# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
home = "/content/drive/MyDrive/College/vision_research/efficiency/Causal-Forcing"
# %cd {home}
# Out:
# /content/drive/MyDrive/College/vision_research/efficiency/Causal-Forcing

# %%
# !ls
# Out:
# assets				     inference.py  requirements.txt
# configs				     LICENSE	   setup.py
# demo.py				     long_video    trainer
# demo_utils			     model	   train.py
# get_causal_ode_data_chunkwise.py     pipeline	   utils
# get_causal_ode_data_framewise.py     prompts	   wan
# get_causal_ode_data_kv_optimized.py  README.md
